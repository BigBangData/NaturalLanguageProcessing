# %% [markdown]
# # Learning Cuves
#
# ---
#
# __This Notebook__
#
# - plot learning curves for the best random forest and adaboost classifiers
# - tweak parameters a bit, without improvement (validates grid search efforts in a way)
#
# __Random Forest and AdaBoost Candidates__
#
# - the original best random forest and AdaBoost classifiers
# - a second random forest that's deeper, which might work well with more data
#
# ```
# rnd_clf1 = RandomForestClassifier(
#     random_state=42
#     , n_estimators=100
#     , max_features=150
#     , max_depth=8
#     , min_samples_split=3
#     , warm_start=True
#     , n_jobs=1
# )
#
# rnd_clf2 = RandomForestClassifier(
#     random_state=42
#     , n_estimators=100
#     , max_features=300 # more features
#     , max_depth=8
#     , min_samples_split=3
#     , warm_start=True
#     , n_jobs=1
# )
#
# ada_clf =  AdaBoostClassifier(
#     random_state=42
#     , n_estimators=10
#     , learning_rate=0.001
# )
# ```
#
#
# __Gradient Boosting Candidates__
#
# ```
# clf1a = GradientBoostingClassifier(
#     random_state=42,
#     n_estimators=50,
#     max_features=None, # default (all features)
#     max_depth=1,
#     min_samples_split=2, # default
#     learning_rate=0.1 # default
# )
#
# clf2a = GradientBoostingClassifier(
#     random_state=42,
#     n_estimators=100, # default
#     max_features=300,
#     max_depth=8,
#     min_samples_split=5,
#     learning_rate=0.1 # default
# )
#
# clf2c = GradientBoostingClassifier(
#     random_state=42,
#     n_estimators=50, # lowered
#     max_features=300,
#     max_depth=3,
#     min_samples_split=5,
#     learning_rate=0.1
# )
#
# ```
#
# __Next__
#
# - could try stacking but Scikit-Learn doesn't offer that out of the box, and I'm ready for model evaluation
# - not using neural nets yet...

# %% [markdown]
# ## Setup

# %%
import re
import os
import time
import joblib 

import numpy as np
import pandas as pd
import scipy.sparse as sp
import matplotlib.pyplot as plt

from datetime import datetime
from sklearn.model_selection import train_test_split, \
    ShuffleSplit, StratifiedKFold, learning_curve
from sklearn.metrics import make_scorer, accuracy_score, \
    recall_score, confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, \
    RandomForestClassifier, GradientBoostingClassifier, \
    VotingClassifier

dt_object = datetime.fromtimestamp(time.time())
day, T = str(dt_object).split('.')[0].split(' ')
print('Revised on: ' + day)
# Out:
# Revised on: 2021-02-17

# %% [markdown]
# ## Load

# %%
# load target 
raw_path = os.path.join("data","1_raw")
y_df = pd.read_csv(os.path.join(raw_path, 'y_train.csv'))
y_array = np.array(y_df.iloc[:,0].ravel())
y = y_array.copy()
y[y=='ham'] = 0
y[y=='spam'] = 1
y = y.astype('int')

# load matrix
proc_dir = os.path.join("data", "2_processed")
X = sp.load_npz(os.path.join(proc_dir, 
                             'X_tfidf_svd800_spamcos.npz'))

# %% [markdown]
# ## Functions

# %%
def train_plot(clf, X, y, cv, verbose, train_sizes, n_jobs, 
               scorer_, metric, axes, axis):
    """
    Trains and plots learning_curves, given:
        scorer_: a make_scorer object
        metric: str, the name of the metric
    ...and all other args passed to learning_curve in the 
    plot_learning_curve function.
    """
    # train
    train_sizes, train_scores, test_scores = \
        learning_curve(clf, X, y, cv=cv, verbose=verbose,
                       train_sizes=train_sizes, n_jobs=n_jobs,
                       scoring=scorer_)
    
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)    
    
    # plot
    axes[axis].grid()
    axes[axis].fill_between(train_sizes, train_scores_mean - train_scores_std,
                         train_scores_mean + train_scores_std, alpha=0.1,
                         color="r")
    axes[axis].fill_between(train_sizes, test_scores_mean - test_scores_std,
                         test_scores_mean + test_scores_std, alpha=0.1,
                         color="g")
    axes[axis].plot(train_sizes, train_scores_mean, 'o-', color="r",
                 label="Training score")
    axes[axis].plot(train_sizes, test_scores_mean, 'o-', color="g",
                 label="Cross-validation score")
    axes[axis].legend(loc="lower right")
    axes[axis].set_ylabel(metric)

# %%
def plot_learning_curve(clf, title, X, y, axes=None, ylim=(.95, 1.01), 
                        cv=5, train_sizes=np.linspace(.1, 1.0, 5),
                        verbose=0, n_jobs=-1):
    """
    Adapted from the Plot Learning Curves example in Scikit-Learn 
    to show only the performance of a scorer, using accuracy, 
    sensitivity, and specificity as metrics.
    """
    # set axes, title, ylims, xlabel
    if axes is None:
        _, axes = plt.subplots(1, 3, figsize=(20, 12))
    
    axes[0].set_title(title)
    axes[2].set_xlabel("Training Examples")
    
    if ylim is not None:
        axes[0].set_ylim(*ylim)
        axes[1].set_ylim(*ylim)
        axes[2].set_ylim(*ylim)

    # setup scorers
    scorers = {
        'acc': make_scorer(accuracy_score),
        'tpr': make_scorer(recall_score, pos_label=1), # sensitivity
        'tnr': make_scorer(recall_score, pos_label=0) # specificity
    }

    # plots
    train_plot(clf, X, y, cv=cv, verbose=verbose, 
               train_sizes=train_sizes, n_jobs=n_jobs, 
               scorer_=scorers['acc'], metric='Accuracy', 
               axes=axes, axis=0)
    train_plot(clf, X, y, cv=cv, verbose=verbose, 
               train_sizes=train_sizes, n_jobs=n_jobs, 
               scorer_=scorers['tpr'], metric='Sensitivity', 
               axes=axes, axis=1)
    train_plot(clf, X, y, cv=cv, verbose=verbose, 
               train_sizes=train_sizes, n_jobs=n_jobs, 
               scorer_=scorers['tnr'], metric='Specificity', 
               axes=axes, axis=2)
    
    return plt

# %%
def compare_two_classifiers(clf1, clf2, title1, title2):
    """
    Wrapper for plot_learning_curve with a timer.
    Compares two classifiers' learning curves.
    """
    t = time.time()
    fig, axes = plt.subplots(3, 2, figsize=(16, 16))
    plot_learning_curve(clf1, title1, X, y, axes=axes[:, 0], cv=cv)
    plot_learning_curve(clf2, title2, X, y, axes=axes[:, 1], cv=cv)
    m, s = divmod(time.time() - t, 60)
    print(f'Elapsed: {m:0.0f} m {s:0.0f} s')
    plt.show()

# %% [markdown]
# ## Comparison plots

# %%
# 10-fold cross validation
cv = ShuffleSplit(n_splits=10, test_size=0.2, random_state=42)

# %% [markdown]
# ### AdaBoost

# %%
title1 = r"AdaBoost, 10 trees, $\eta=0.001$"
title2 = r"AdaBoost, 10 trees, $\eta=0.01$"

clf1 =  AdaBoostClassifier(
    random_state=42
    , n_estimators=10
    , learning_rate=0.001
)

clf2 =  AdaBoostClassifier(
    random_state=42
    , n_estimators=10
    , learning_rate=0.01 
)

compare_two_classifiers(clf1, clf2, title1, title2)
# Out:
# Elapsed: 2 m 16 s

# %% [markdown]
# Not overfitting, possibly underfitting a bit.

# %%
title1 = r"AdaBoost, 20 trees, $\eta=0.001$"
title2 = r"AdaBoost, 20 trees, $\eta=0.01$"

clf1 =  AdaBoostClassifier(
    random_state=42
    , n_estimators=20 
    , learning_rate=0.001
)

clf2 =  AdaBoostClassifier(
    random_state=42
    , n_estimators=20
    , learning_rate=0.01 
)

compare_two_classifiers(clf1, clf2, title1, title2)
# Out:
# Elapsed: 4 m 32 s

# %% [markdown]
# No significant change with 20 trees.

# %%
title1 = r"AdaBoost, 50 trees, $\eta=0.005$"
title2 = r"AdaBoost, 50 trees, $\eta=0.05$"

clf1 =  AdaBoostClassifier(
    random_state=42
    , n_estimators=50 
    , learning_rate=0.005
)

clf2 =  AdaBoostClassifier(
    random_state=42
    , n_estimators=50 
    , learning_rate=0.05
)

compare_two_classifiers(clf1, clf2, title1, title2)
# Out:
# Elapsed: 11 m 17 s

# %% [markdown]
# No significant change...

# %%
title1 = r"AdaBoost, 100 trees, $\eta=0.005$"
title2 = r"AdaBoost, 100 trees, $\eta=0.05$"

clf1 =  AdaBoostClassifier(
    random_state=42
    , n_estimators=100 
    , learning_rate=0.005 
)

clf2 =  AdaBoostClassifier(
    random_state=42
    , n_estimators=100 
    , learning_rate=0.05
)

compare_two_classifiers(clf1, clf2, title1, title2)
# Out:
# Elapsed: 22 m 21 s

# %% [markdown]
# No significant change either. Done with AdaBoost, the first model was good enough, but not great.

# %% [markdown]
# ### Random Forests

# %%
title1 = r"RandomForest, 100 trees, 150 feat, depth 8, split 3"
title2 = r"RandomForest, 100 trees, 150 feat, depth 8, split 2"

clf1 = RandomForestClassifier(
    random_state=42
    , n_estimators=100
    , max_features=150
    , max_depth=8
    , min_samples_split=3
    , warm_start=True
    , n_jobs=1
)

clf2 = RandomForestClassifier(
    random_state=42
    , n_estimators=100 
    , max_features=150
    , max_depth=8
    , min_samples_split=2 
    , warm_start=True
    , n_jobs=1
)

compare_two_classifiers(clf1, clf2, title1, title2)
# Out:
# Elapsed: 12 m 38 s

# %% [markdown]
# The original `min_samples_split=3` is clearly advantageous. Not a bad classifier but we're out of data...

# %% [markdown]
# #### Higher min_samples_split

# %%
title1 = r"RandomForest, 100 trees, 150 feat, depth 8, split 4"
title2 = r"RandomForest, 100 trees, 150 feat, depth 8, split 5"

clf1 = RandomForestClassifier(
    random_state=42
    , n_estimators=100
    , max_features=150
    , max_depth=8
    , min_samples_split=4
    , warm_start=True
    , n_jobs=1
)

clf2 = RandomForestClassifier(
    random_state=42
    , n_estimators=100 
    , max_features=150
    , max_depth=8
    , min_samples_split=5
    , warm_start=True
    , n_jobs=1
)

compare_two_classifiers(clf1, clf2, title1, title2)
# Out:
# Elapsed: 13 m 1 s

# %% [markdown]
# No great results, validation sensitivity seems to plateau.

# %% [markdown]
# #### More Features

# %%
title1 = r"RandomForest, 100 trees, 300 feat, depth 8, split 3"
title2 = r"RandomForest, 100 trees, 600 feat, depth 8, split 3"

clf1 = RandomForestClassifier(
    random_state=42
    , n_estimators=100
    , max_features=300
    , max_depth=8
    , min_samples_split=3
    , warm_start=True
    , n_jobs=1
)

clf2 = RandomForestClassifier(
    random_state=42
    , n_estimators=100 
    , max_features=600
    , max_depth=8
    , min_samples_split=3
    , warm_start=True
    , n_jobs=1
)

compare_two_classifiers(clf1, clf2, title1, title2)
# Out:
# Elapsed: 48 m 34 s

# %% [markdown]
# 300 features is promising for a project with more data, if (big if) this learning curve is similar in this other project.

# %% [markdown]
# #### Shallower max_depth

# %%
title1 = r"RandomForest, 100 trees, 150 feat, depth 4, split 3"
title2 = r"RandomForest, 100 trees, 150 feat, depth 2, split 3"

clf1 = RandomForestClassifier(
    random_state=42
    , n_estimators=100
    , max_features=150
    , max_depth=4
    , min_samples_split=3
    , warm_start=True
    , n_jobs=1
)

clf2 = RandomForestClassifier(
    random_state=42
    , n_estimators=100 
    , max_features=150
    , max_depth=2
    , min_samples_split=3
    , warm_start=True
    , n_jobs=1
)

compare_two_classifiers(clf1, clf2, title1, title2)
# Out:
# Elapsed: 11 m 48 s

# %% [markdown]
# Shallower forests with 100 trees don't work so well.

# %% [markdown]
# #### More Trees

# %%
title1 = r"RandomForest, 200 trees, 150 feat, depth 8, split 3"
title2 = r"RandomForest, 400 trees, 150 feat, depth 8, split 3"

clf1 = RandomForestClassifier(
    random_state=42
    , n_estimators=200
    , max_features=150
    , max_depth=8
    , min_samples_split=3
    , warm_start=True
    , n_jobs=1
)

clf2 = RandomForestClassifier(
    random_state=42
    , n_estimators=400 
    , max_features=150
    , max_depth=8
    , min_samples_split=3
    , warm_start=True
    , n_jobs=1
)

compare_two_classifiers(clf1, clf2, title1, title2)
# Out:
# Elapsed: 60 m 42 s

# %% [markdown]
# More trees and similar depth just takes too long and doesn't yield great results.
#
# #### Large Forest of Shallow Trees

# %%
title1 = r"RandomForest, 300 trees, 150 feat, depth 2, split 3"
title2 = r"RandomForest, 300 trees, 150 feat, depth 4, split 3"

clf1 = RandomForestClassifier(
    random_state=42
    , n_estimators=300
    , max_features=150
    , max_depth=2
    , min_samples_split=3
    , warm_start=True
    , n_jobs=1
)

clf2 = RandomForestClassifier(
    random_state=42
    , n_estimators=300 
    , max_features=150
    , max_depth=4
    , min_samples_split=3
    , warm_start=True
    , n_jobs=1
)

compare_two_classifiers(clf1, clf2, title1, title2)
# Out:
# Elapsed: 19 m 26 s

# %% [markdown]
# Depth=2 is very bad, depth=3 is just regular bad.

# %% [markdown]
# ### Deep Trees

# %%
title1 = r"RandomForest, 100 trees, 150 feat, depth 10, split 3"
title2 = r"RandomForest, 100 trees, 150 feat, depth 15, split 3"

clf1 = RandomForestClassifier(
    random_state=42
    , n_estimators=100
    , max_features=150
    , max_depth=10
    , min_samples_split=3
    , warm_start=True
    , n_jobs=1
)

clf2 = RandomForestClassifier(
    random_state=42
    , n_estimators=100 
    , max_features=150
    , max_depth=15
    , min_samples_split=3
    , warm_start=True
    , n_jobs=1
)

compare_two_classifiers(clf1, clf2, title1, title2)
# Out:
# Elapsed: 13 m 33 s

# %% [markdown]
# Deeper trees don't seem to present an advantage either.

# %% [markdown]
# ---
